# %% [markdown]
# <a href="https://colab.research.google.com/github/TaynaraLacerda/Aula-14-04/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# COMANDO INPUT

# %%
nome = input("digite o seu nome:  ")
print("O seu nome é:", nome)
# Out:
# digite o seu nome:  LUIZ
# O seu nome é: LUIZ

# %%
valor1 = int(input("Digite o seu valor:  "))
valor2 = int(input("Digite o seu valor:"  ))
resultado = valor1 + valor2
print(resultado)
# Out:
# Digite o seu valor:  10
# Digite o seu valor:10
# 20

# %%
valor1 = int(input("Digite o seu valor:  "))
valor2 = int(input("Digite o seu valor:"  ))
print(valor1 + valor2)
# Out:
# Digite o seu valor:  10
# Digite o seu valor:10
# 20

# %%
# atividade 01
# valor1 = int(input("Digite o seu valor:  "))
# valor2 = int(input("Digite o seu valor:  "))
# resultado = valor1 + valor2
print(resultado)
# Out:
# 20

# %%
# atividade 02
valor1 = int(input("Digite um número:  "))
valor2 = int(input("Digite um número:  "))
resultado = valor1 - valor2
print(resultado)
# Out:
# Digite um número:  10
# Digite um número:  5
# 5

# %%
# atividade 3
valor1 = int(input("Digite um número:  "))
valor2 = int(input("Digite um número:  "))
Resultado1 = valor1 + valor2
Resultado2 = valor1 - valor2
Resultado3 = valor1 * valor2
Resultado4 = valor1 / valor2
print("soma:",Resultado1)
print("subtração:",Resultado2)
print("multiplicação:",Resultado3)
print("divisão:",Resultado4)
# Out:
# Digite um número:  60
# Digite um número:  20
# soma: 80
# subtração: 40
# multiplicação: 1200
# divisão: 3.0

# %%
# atividade 4
usuario = input("Digite o seu nome: ")
print("Olá",usuario," Seja bem vindo!")
# Out:
# Digite o seu nome: Taynara
# Olá Taynara  Seja bem vindo!
